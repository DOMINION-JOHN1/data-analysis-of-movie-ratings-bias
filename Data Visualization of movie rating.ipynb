# %% [markdown]
# **import**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fandango = pd.read_csv("fandango_scrape.csv")

# %%
fandango.head()
# Out:
#                           FILM  STARS  RATING  VOTES
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1        Jurassic World (2015)    4.5     4.5  34390
# 2       American Sniper (2015)    5.0     4.8  34085
# 3             Furious 7 (2015)    5.0     4.8  33538
# 4            Inside Out (2015)    4.5     4.5  15749

# %%
fandango.describe()
# Out:
#             STARS      RATING         VOTES
# count  504.000000  504.000000    504.000000
# mean     3.558532    3.375794   1147.863095
# std      1.563133    1.491223   3830.583136
# min      0.000000    0.000000      0.000000
# 25%      3.500000    3.100000      3.000000
# 50%      4.000000    3.800000     18.500000
# 75%      4.500000    4.300000    189.750000
# max      5.000000    5.000000  34846.000000

# %%
fandango.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   FILM    504 non-null    object
#  1   STARS   504 non-null    float64
#  2   RATING  504 non-null    float64
#  3   VOTES   504 non-null    int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 15.9+ KB

# %% [markdown]
# **EDA**

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.scatterplot(data=fandango,x='RATING',y='VOTES');

# %%
fandango.corr()
# Out:
#            STARS    RATING     VOTES
# STARS   1.000000  0.994696  0.164218
# RATING  0.994696  1.000000  0.163764
# VOTES   0.164218  0.163764  1.000000

# %%
title = "Film Title Name (Year)"

# %%
fandango['YEAR'] = fandango['FILM'].apply(lambda title:title.split('(')[-1].replace(")",""))

# %%
fandango.head()
# Out:
#                           FILM  STARS  RATING  VOTES  YEAR
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846  2015
# 1        Jurassic World (2015)    4.5     4.5  34390  2015
# 2       American Sniper (2015)    5.0     4.8  34085  2015
# 3             Furious 7 (2015)    5.0     4.8  33538  2015
# 4            Inside Out (2015)    4.5     4.5  15749  2015

# %%
fandango['YEAR'].value_counts()
# Out:
# 2015    478
# 2014     23
# 1964      1
# 2012      1
# 2016      1
# Name: YEAR, dtype: int64

# %%
sns.countplot(data=fandango,x='YEAR')
# Out:
# <AxesSubplot:xlabel='YEAR', ylabel='count'>

# %%
fandango.nlargest(10,'VOTES')
# Out:
#                                                FILM  STARS  RATING  VOTES  \
# 0                       Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1                             Jurassic World (2015)    4.5     4.5  34390
# 2                            American Sniper (2015)    5.0     4.8  34085
# 3                                  Furious 7 (2015)    5.0     4.8  33538
# 4                                 Inside Out (2015)    4.5     4.5  15749
# 5  The Hobbit: The Battle of the Five Armies (2014)    4.5     4.3  15337
# 6               Kingsman: The Secret Service (2015)    4.5     4.2  15205
# 7                                    Minions (2015)    4.0     4.0  14998
# 8                    Avengers: Age of Ultron (2015)    5.0     4.5  14846
# 9                             Into the Woods (2014)    3.5     3.4  13055
#
#    YEAR
# 0  2015
# 1  2015
# 2  2015
# 3  2015
# 4  2015
# 5  2014
# 6  2015
# 7  2015
# 8  2015
# 9  2014

# %%
no_votes = fandango['VOTES']==0
no_votes.sum()
# Out:
# 69

# %%
fan_reviewed = fandango[fandango['VOTES']>0]

# %% [markdown]
# **As noted in the article, due to HTML and star rating displays, the true user rating may be slightly different from the rating shown to a user. Let's visualize this difference in distributions.**

# %%
plt.figure(figsize=(10,4),dpi=150)
sns.kdeplot(data=fan_reviewed,x='RATING',clip=[0,5],fill=True,label='True Rating')
sns.kdeplot(data=fan_reviewed,x='STARS',clip=[0,5],fill=True,label='Stars Displayed')

plt.legend(loc=(1.05,0.5))

# %% [markdown]
# **Let's now actually quantify this discrepancy. Create a new column of the different between STARS displayed versus true RATING. Calculate this difference with STARS-RATING and round these differences to the nearest decimal point.**

# %%
fan_reviewed["STARS_DIFF"] = fan_reviewed['STARS'] - fan_reviewed['RATING']
fan_reviewed['STARS_DIFF'] = fan_reviewed['STARS_DIFF'].round(2)
# Out:
# <ipython-input-18-937753ca13ef>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fan_reviewed["STARS_DIFF"] = fan_reviewed['STARS'] - fan_reviewed['RATING']
# <ipython-input-18-937753ca13ef>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fan_reviewed['STARS_DIFF'] = fan_reviewed['STARS_DIFF'].round(2)

# %%
fan_reviewed
# Out:
#                             FILM  STARS  RATING  VOTES  YEAR  STARS_DIFF
# 0    Fifty Shades of Grey (2015)    4.0     3.9  34846  2015         0.1
# 1          Jurassic World (2015)    4.5     4.5  34390  2015         0.0
# 2         American Sniper (2015)    5.0     4.8  34085  2015         0.2
# 3               Furious 7 (2015)    5.0     4.8  33538  2015         0.2
# 4              Inside Out (2015)    4.5     4.5  15749  2015         0.0
# ..                           ...    ...     ...    ...   ...         ...
# 430       That Sugar Film (2015)    5.0     5.0      1  2015         0.0
# 431            The Intern (2015)    5.0     5.0      1  2015         0.0
# 432        The Park Bench (2015)    5.0     5.0      1  2015         0.0
# 433         The Wanted 18 (2015)    5.0     5.0      1  2015         0.0
# 434       Z For Zachariah (2015)    5.0     5.0      1  2015         0.0
#
# [435 rows x 6 columns]

# %%
plt.figure(figsize=(12,4),dpi=150)
sns.countplot(data=fan_reviewed,x='STARS_DIFF',palette='magma')
# Out:
# <AxesSubplot:xlabel='STARS_DIFF', ylabel='count'>

# %%
fan_reviewed[fan_reviewed['STARS_DIFF'] == 1]
# Out:
#                  FILM  STARS  RATING  VOTES  YEAR  STARS_DIFF
# 381  Turbo Kid (2015)    5.0     4.0      2  2015         1.0

# %%
all_sites = pd.read_csv("all_sites_scores.csv")

# %%
all_sites.head()
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 0          66              7.1   7.8                        1330
# 1          67              7.5   7.1                         249
# 2          64              8.1   7.8                         627
# 3          22              4.7   5.4                          31
# 4          29              3.4   5.1                          88
#
#    IMDB_user_vote_count
# 0                271107
# 1                 65709
# 2                103660
# 3                  3136
# ...

# %%
all_sites.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   FILM                        146 non-null    object
#  1   RottenTomatoes              146 non-null    int64
#  2   RottenTomatoes_User         146 non-null    int64
#  3   Metacritic                  146 non-null    int64
#  4   Metacritic_User             146 non-null    float64
#  5   IMDB                        146 non-null    float64
#  6   Metacritic_user_vote_count  146 non-null    int64
#  7   IMDB_user_vote_count        146 non-null    int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 9.2+ KB

# %%
all_sites.describe()
# Out:
#        RottenTomatoes  RottenTomatoes_User  Metacritic  Metacritic_User  \
# count      146.000000           146.000000  146.000000       146.000000
# mean        60.849315            63.876712   58.808219         6.519178
# std         30.168799            20.024430   19.517389         1.510712
# min          5.000000            20.000000   13.000000         2.400000
# 25%         31.250000            50.000000   43.500000         5.700000
# 50%         63.500000            66.500000   59.000000         6.850000
# 75%         89.000000            81.000000   75.000000         7.500000
# max        100.000000            94.000000   94.000000         9.600000
#
#              IMDB  Metacritic_user_vote_count  IMDB_user_vote_count
# count  146.000000                  146.000000            146.000000
# mean     6.736986                  185.705479          42846.205479
# std      0.958736                  316.606515          67406.509171
# ...

# %%
plt.figure(figsize=(10,4),dpi=150)
sns.scatterplot(data=all_sites,x='RottenTomatoes',y='RottenTomatoes_User')
plt.xlim(0,100)
plt.ylim(0,100)
# Out:
# (0.0, 100.0)

# %% [markdown]
# Let's quantify this difference by comparing the critics ratings and the RT User ratings. We will calculate this with RottenTomatoes-RottenTomatoes_User. Note: Rotten_Diff here is Critics - User Score. So values closer to 0 means aggrement between Critics and Users. Larger positive values means critics rated much higher than users. Larger negative values means users rated much higher than critics.

# %%
all_sites['Rotten_Diff']  = all_sites['RottenTomatoes'] - all_sites['RottenTomatoes_User']

# %% [markdown]
# Let's now compare the overall mean difference. Since we're dealing with differences that could be negative or positive, first take the absolute value of all the differences, then take the mean. This would report back on average to absolute difference between the critics rating versus the user rating.

# %%
all_sites['Rotten_Diff'].apply(abs).mean()
# Out:
# 15.095890410958905

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.histplot(data=all_sites,x='Rotten_Diff',kde=True,bins=25)
plt.title("RT Critics Score minus RT User Score");

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.histplot(x=all_sites['Rotten_Diff'].apply(abs),bins=25,kde=True)
plt.title("Abs Difference between RT Critics Score and RT User Score");

# %% [markdown]
# **Let's find out which movies are causing the largest differences. First, show the top 5 movies with the largest *negative* difference between Users and RT critics. Since we calculated the difference as Critics Rating - Users Rating, then large negative values imply the users rated the movie much higher on average than the critics did.**

# %%
print("Users Love but Critics Hate")
all_sites.nsmallest(5,'Rotten_Diff')[['FILM','Rotten_Diff']]
# Out:
# Users Love but Critics Hate
#                           FILM  Rotten_Diff
# 3       Do You Believe? (2015)          -66
# 85           Little Boy (2015)          -61
# 105    Hitman: Agent 47 (2015)          -42
# 134    The Longest Ride (2015)          -42
# 125  The Wedding Ringer (2015)          -39

# %%
print("Critics love, but Users Hate")
all_sites.nlargest(5,'Rotten_Diff')[['FILM','Rotten_Diff']]
# Out:
# Critics love, but Users Hate
#                                  FILM  Rotten_Diff
# 69                  Mr. Turner (2014)           42
# 112                 It Follows (2015)           31
# 115          While We're Young (2015)           31
# 37               Welcome to Me (2015)           24
# 40   I'll See You In My Dreams (2015)           24

# %% [markdown]
# ## MetaCritic
#
# Now let's take a quick look at the ratings from MetaCritic. Metacritic also shows an average user rating versus their official displayed rating.

# %%
plt.figure(figsize=(10,4),dpi=150)
sns.scatterplot(data=all_sites,x='Metacritic',y='Metacritic_User')
plt.xlim(0,100)
plt.ylim(0,10)
# Out:
# (0.0, 10.0)

# %% [markdown]
# ## IMBD
#
# Finally, let's explore IMDB. Notice that both Metacritic and IMDB report back vote counts. Let's analyze the most popular movies

# %%
plt.figure(figsize=(10,4),dpi=150)
sns.scatterplot(data=all_sites,x='Metacritic_user_vote_count',y='IMDB_user_vote_count')
# Out:
# <AxesSubplot:xlabel='Metacritic_user_vote_count', ylabel='IMDB_user_vote_count'>

# %% [markdown]
# **Notice there are two outliers here. The movie with the highest vote count on IMDB only has about 500 Metacritic ratings. We want to get the  movie?**

# %%
all_sites.nlargest(1,'IMDB_user_vote_count')
# Out:
#                          FILM  RottenTomatoes  RottenTomatoes_User  \
# 14  The Imitation Game (2014)              90                   92
#
#     Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 14          73              8.2   8.1                         566
#
#     IMDB_user_vote_count  Rotten_Diff
# 14                334164           -2

# %% [markdown]
# **We want to get the movie with the highest Metacritic User Vote count?**

# %%
all_sites.nlargest(1,'Metacritic_user_vote_count')
# Out:
#                          FILM  RottenTomatoes  RottenTomatoes_User  \
# 88  Mad Max: Fury Road (2015)              97                   88
#
#     Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 88          89              8.7   8.3                        2375
#
#     IMDB_user_vote_count  Rotten_Diff
# 88                292023            9

# %% [markdown]
# ## Fandago Scores vs. All Sites
#
# Finally, let's begin to explore whether  Fandango artificially displays higher ratings than warranted to boost ticket sales.
#
# **We will Combine the Fandango Table with All Sites table. Not every movie in the Fandango table is in All Sites table, since some Fandango movies have very little or no reviews. We only want to compare movies that are in both DataFrames, so do an *inner* merge to merge together both DataFrames based on the FILM columns.**

# %%
df = pd.merge(fandango,all_sites,on='FILM')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 145 entries, 0 to 144
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   FILM                        145 non-null    object
#  1   STARS                       145 non-null    float64
#  2   RATING                      145 non-null    float64
#  3   VOTES                       145 non-null    int64
#  4   YEAR                        145 non-null    object
#  5   RottenTomatoes              145 non-null    int64
#  6   RottenTomatoes_User         145 non-null    int64
#  7   Metacritic                  145 non-null    int64
#  8   Metacritic_User             145 non-null    float64
#  9   IMDB                        145 non-null    float64
#  10  Metacritic_user_vote_count  145 non-null    int64
#  11  IMDB_user_vote_count        145 non-null    int64
#  12  Rotten_Diff                 145 non-null    int64
# ...

# %%
df.columns
# Out:
# Index(['FILM', 'STARS', 'RATING', 'VOTES', 'YEAR', 'RottenTomatoes',
#        'RottenTomatoes_User', 'Metacritic', 'Metacritic_User', 'IMDB',
#        'Metacritic_user_vote_count', 'IMDB_user_vote_count', 'Rotten_Diff'],
#       dtype='object')

# %% [markdown]
# ### Normalize columns to Fandango STARS and RATINGS 0-5
#
# Notice that RT,Metacritic, and IMDB don't use a score between 0-5 stars like Fandango does. In order to do a fair comparison, we need to **normalize** these values, so they all fall between 0-5 stars and the relationship between reviews stays the same. We will be using the min max scaler.

# %%
new_df=df[['STARS','RATING','RottenTomatoes',
       'RottenTomatoes_User', 'Metacritic', 'Metacritic_User', 'IMDB']]

# %%
normalized_df=(new_df-new_df.min())/(new_df.max()-new_df.min())

# %%
normalized_df
# Out:
#      STARS    RATING  RottenTomatoes  RottenTomatoes_User  Metacritic  \
# 0     0.50  0.571429        0.210526             0.297297    0.407407
# 1     0.75  0.857143        0.694737             0.824324    0.567901
# 2     1.00  1.000000        0.705263             0.878378    0.728395
# 3     1.00  1.000000        0.800000             0.864865    0.666667
# 4     0.75  0.857143        0.978947             0.945946    1.000000
# ..     ...       ...             ...                  ...         ...
# 140   0.25  0.380952        0.863158             0.581081    0.679012
# 141   0.50  0.428571        0.947368             0.824324    0.913580
# 142   0.75  0.714286        0.926316             0.864865    0.666667
# 143   0.50  0.571429        0.947368             0.891892    0.901235
# 144   0.25  0.190476        0.578947             0.351351    0.666667
#
#      Metacritic_User      IMDB
# 0           0.111111  0.043478
# 1           0.638889  0.717391
# ...

# %% [markdown]
# We will visualize all the ratings from all sites and fandango, so we can compare them to each other and see the degree of fandango ratings from all other

# %%
def move_legend(ax, new_loc, **kws):
    old_legend = ax.legend_
    handles = old_legend.legendHandles
    labels = [t.get_text() for t in old_legend.get_texts()]
    title = old_legend.get_title().get_text()
    ax.legend(handles, labels, loc=new_loc, title=title, **kws)

# %%
fig, ax = plt.subplots(figsize=(15,6),dpi=150)
sns.kdeplot(data=normalized_df,shade=True,palette='Set1',ax=ax)
move_legend(ax, "upper right")

# %% [markdown]
# **Clearly Fandango has an uneven distribution. We can also see that RT critics have the most uniform distribution. Let's directly compare these two.**

# %%
fig, ax = plt.subplots(figsize=(15,6),dpi=150)
sns.kdeplot(data=normalized_df[['RottenTomatoes','STARS']],clip=[0,5],shade=True,palette='Set1',ax=ax)
move_legend(ax, "upper left")

# %% [markdown]
# we will create a histplot to compare all the normalized rating

# %%
plt.subplots(figsize=(15,6),dpi=150)
sns.histplot(normalized_df,bins=50)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.clustermap(normalized_df,cmap='magma',col_cluster=False)

# %% [markdown]
# **Clearly  from the clustermap Fandango is rating movies much more different from other sites. Let's examine the top 10 worst movies.**

# %%
film = df[['FILM']]
normalized_df ['FILM'] = film

# %%
normalized_df
# Out:
#      STARS    RATING  RottenTomatoes  RottenTomatoes_User  Metacritic  \
# 0     0.50  0.571429        0.210526             0.297297    0.407407
# 1     0.75  0.857143        0.694737             0.824324    0.567901
# 2     1.00  1.000000        0.705263             0.878378    0.728395
# 3     1.00  1.000000        0.800000             0.864865    0.666667
# 4     0.75  0.857143        0.978947             0.945946    1.000000
# ..     ...       ...             ...                  ...         ...
# 140   0.25  0.380952        0.863158             0.581081    0.679012
# 141   0.50  0.428571        0.947368             0.824324    0.913580
# 142   0.75  0.714286        0.926316             0.864865    0.666667
# 143   0.50  0.571429        0.947368             0.891892    0.901235
# 144   0.25  0.190476        0.578947             0.351351    0.666667
#
#      Metacritic_User      IMDB                                FILM
# ...

# %% [markdown]
# **We want to  compare the rating of the worst reviewed movies from fandango and all_sites**

# %%
print('\n\n')
plt.figure(figsize=(15,6),dpi=150)
worst_films = normalized_df.nsmallest(10,'RottenTomatoes').drop('FILM',axis=1)
sns.kdeplot(data=worst_films,shade=True,palette='Set1')
plt.title("Ratings for RottenTomatoes Critic's 10 Worst Reviewed Films");

# %% [markdown]
# **From the kdeplot you will notice fandago rating were very high for movies that was rated low by other reviewers, this further proves that fandango reviewers are always on average way more higher than reviews from other sites**

# %%
normalized_df.nsmallest(10,'RottenTomatoes')
# Out:
#     STARS    RATING  RottenTomatoes  RottenTomatoes_User  Metacritic  \
# 49   0.25  0.380952        0.000000             0.216216    0.000000
# 84   0.50  0.571429        0.021053             0.391892    0.185185
# 54   0.50  0.476190        0.031579             0.229730    0.222222
# 25   0.75  0.666667        0.042105             0.351351    0.160494
# 28   0.00  0.000000        0.042105             0.000000    0.172840
# 50   0.50  0.428571        0.052632             0.202703    0.209877
# 87   0.25  0.238095        0.063158             0.094595    0.234568
# 88   0.50  0.428571        0.063158             0.270270    0.135802
# 77   0.25  0.238095        0.073684             0.202703    0.209877
# 78   0.25  0.238095        0.073684             0.135135    0.172840
#
#     Metacritic_User      IMDB                           FILM
# 49         0.000000  0.065217  Paul Blart: Mall Cop 2 (2015)
# 84         0.125000  0.413043        Hitman: Agent 47 (2015)
# ...

# %% [markdown]
# **Final thoughts: Wow! Fandango is showing around 0.5-0.75 star ratings for films that are clearly bad! Notice the biggest offender,Hot Pursuit. Fandango is displaying 0.25 stars on their site for a film with an [average rating of 0.056] across the other platforms!**

# %%
normalized_df.iloc[49]
# Out:
# STARS                                           0.25
# RATING                                      0.380952
# RottenTomatoes                                     0
# RottenTomatoes_User                         0.216216
# Metacritic                                         0
# Metacritic_User                                    0
# IMDB                                       0.0652174
# FILM                   Paul Blart: Mall Cop 2 (2015)
# Name: 49, dtype: object

# %%
(0+0.216216+0+0+0.0652174)/5
# Out:
# 0.05628668
